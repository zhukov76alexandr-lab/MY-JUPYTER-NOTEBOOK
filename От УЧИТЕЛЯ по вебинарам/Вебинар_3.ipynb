# %% [markdown]
# # Вебинар 3: Бинарные и унарные операции, переменные, условия

# %% [markdown]
# ## Проверка связи

# %% [markdown]
# **Если у вас нет звука:**
# - убедитесь, что на вашем устройстве
# и в колонках включён звук
# - обновите страницу вебинара или закройте страницу и заново присоединитесь к вебинару
# - откройте вебинар в другом браузере
# - перезагрузите ваше устройство
# и  попытайтесь войти снова

# %% [markdown]
# **Поставьте в чат:**<br>
# \+ если меня видно и слышно<br>
# \- если нет

# %% [markdown]
# ## О спикере

# %% [markdown]
# **Филипп Воронов**
# - тимлид в VK
# - преподаватель в Нетологии, Яндекс Практикуме, Университете ИТМО, GeekBrains, Computer Science Center, Bang Bang Education

# %% [markdown]
# ## Правила участия

# %% [markdown]
# 1. Продолжительность вебинара — 80 минут. Через 40 минут сделаем перерыв на 5 минут
# 2. Запустите IDE для выполнения практических заданий вебинара. Во время демонстрации работы повторяйте за преподавателем: так вы лучше поймёте материал
# 3. Вопросы и уточнения:
#   - создайте копию этого блокнота, чтобы фиксировать вопросы и важную информацию во время занятия
#   - вы можете писать вопросы в чате во время вебинара или озвучивать их в блоке «Ваши вопросы»
# 4. Запись вебинара будет доступна в личном кабинете

# %% [markdown]
# ## Цель занятия

# %% [markdown]
# Расширить область знаний в части бинарных и унарных операций, переменных, условных конструкций в Python

# %% [markdown]
# ## План занятия

# %% [markdown]
# [1. Арифметические операции](#2.-Арифметические-операции)<br>
# [2. Переменные](#3.-Переменные)<br>
# [3. Строки](#4.-Строки)<br>
# [4. Операторы сравнения](#5.-Операторы-сравнения)<br>
# [5. Условные конструкции](#6.-Условные-конструкции)<br>
# [6. Пишем программу для отбора кандидаток в модельное агентство](#7.-Пишем-программу-для-отбора-кандидаток-в-модельное-агентство)<br>
# [7. Логические операторы and и or](#8.-Логические-операторы-and-и-or)<br>

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## 1. Арифметические операции

# %%
print(1 + 1)
# Out:
# 2

# %%
print(2 - 1, 5 + 6)
# Out:
# 1 11

# %%
print(2-1)

# %%
# ...
1 + 1 # Для вывода в Jupyter Notebook необязательно использовать print

# %%
1 + 1
2 - 1

# %%
print(1 + 1)
print(2 - 1)

# %%
5 * 6

# %%
10 / 4

# %%
10 // 4

# %%
10 = 4*2 + 2

# %%
2 ** 100

# %%
2*2*2*2*2

# %%
-4 % 3

# %%
5 - (3 + 2) * 6

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## 2. Переменные

# %%
a = 10 + 20
b = a * 30
c = a / b
print('Ответ: ', a, b, c)

# %%
b

# %% [markdown]
# Переменная должна объявляться до её использования

# %%
x = 10
print(x)

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## 3. Строки

# %%
my_string_1 = 'He said: "Hello"'

# %%
my_string_2 = "Hello \"World!"

# %%
my_string_1

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## 4. Операторы сравнения

# %%
++1

# %%
2 > 1

# %%
10 < 9

# %%
10 > 10

# %%
10 >= 10

# %%
7 == 7

# %%
a = 1

# %%
a == 1

# %%
<>

# %%
15 != 15

# %%
5 > 4 < 0

# %%
# Сравнение строк
print('c' > 'a')

# %%
print('b' > 'B')

# %%
print('abc' > 'aba')

# %%
len('abc') > len('dfhjdfj')

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## 5. Условные конструкции

# %%
a = 1
b = 2

if a < b and 2 > 1 and (2 > 1 or 2 > 1):
    print('Значение переменной a меньше b')

# %%
x = 6
if x % 2 == 0:
    print(x, '- четное число')

# %%
x = 5
if x % 2 == 0:
    print(x, '- четное число')
else:
    print(x, '- нечетное число')

# %%
'2020-05-01' < '2020-05-09'

# %%
'2019-12-31' < '2020-01-01'

# %%
'logs_2020-02-29.csv' < 'logs_2020-03-01.csv'

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# # 6. Пишем программу для отбора кандидаток в модельное агентство

# %%
height = 180
if height < 170:
    print('Группа моделей до 170 см')

print('Конец программы')
# Out:
# Конец программы

# %%
if height < 170:
    print('Группа моделей до 170 см')
else:
    print('В другую группу моделей')
print('Конец программы')
# Out:
# В другую группу моделей
# Конец программы

# %%
# Условия выполняются по порядку.  Как только одно выполнено, проверки останавливаются
height = 210
if height < 170:
    print('Группа моделей до 170 см')
elif height < 200:
    print('Группа моделей от 170 см до 180 см')
else:
    print('В другую группу моделей')
print('Конец программы')

# %%
# Блоков elif может быть сколько угодно
height = 210
if height < 170:
    print('Группа моделей до 170 см')
elif height < 180:
    print('Группа моделей от 170 см до 180 см')
elif height < 200:
    print('Группа моделей от 180 см до 200 см')
else:
    print('В другую группу моделей')
print('Конец программы')

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## 7. Логические операторы and и or

# %%
True and True

# %%
True and False

# %%
True or False

# %%
not True

# %%
((9 > 7) and (2 < 4))

# %%
(8 == 8) or (6 != 6)

# %%
not(3 <= 1)

# %%
age = 15
height = 180

if height < 170 and age >= 18:
    print('Группа моделей до 170 см и возраст больше 18 лет')
elif height < 185 and age >= 18:
    print('Группа моделей до 185 см и возраст больше 18 лет')
elif height < 200 and age >= 18:
    print('Группа моделей до 200 см и возраст больше 18 лет')
else:
    print('В другую группу моделей')
print('Конец программы')

# %%
age = 21
if age >= 18:
    user_input = int(input('Введите рост'))
    if user_input < 170:
        print('Группа моделей до 170 см и возраст больше 18 лет')
    elif user_input < 185:
        print('Группа моделей до 185 см и возраст больше 18 лет')
    elif user_input < 200:
        print('Группа моделей до 200 см и возраст больше 18 лет')
    else:
        print('В другую группу моделей')
else:
    print('В модели не подходит')
print('Конец программы')

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## Итоги занятия

# %% [markdown]
# Расширили область знаний в части бинарных и унарных операций, переменных, условных конструкций

# %% [markdown]
# ## Ваши вопросы
